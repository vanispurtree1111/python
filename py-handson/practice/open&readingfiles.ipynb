# %%
import os

# %%
os.getcwd()
# current working directory
# Out:
# 'C:\\Users\\Vani\\python\\practice'

# %%
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  'datatypes.ipynb',
#  'Dictionaries.ipynb',
#  'errorhandling.ipynb',
#  'firstnotebook.ipynb',
#  'forloops.ipynb',
#  'functions.ipynb',
#  'ifelsecondt.ipynb',
#  'listcomphr.ipynb',
#  'Lists.ipynb',
#  'methods.ipynb',
#  'oops.ipynb',
#  'open&readingfiles.ipynb',
#  'sets&boolean.ipynb',
#  'stringIndexing-slicing.ipynb',
#  'testfile',
#  'Tuple.ipynb',
#  'Untitled.ipynb',
#  'Untitled1.ipynb',
#  'Untitled2.ipynb',
#  'Untitled3.ipynb',
#  'usefulOperators.ipynb',
#  'whileloop.ipynb']

# %%
import shutil
# to shift/ move the file / directory

# %%
shutil.move('testfile','C:\\Users\\Vani\\python')
# Out:
# 'C:\\Users\\Vani\\python\\testfile'

# %%
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  'datatypes.ipynb',
#  'Dictionaries.ipynb',
#  'errorhandling.ipynb',
#  'firstnotebook.ipynb',
#  'forloops.ipynb',
#  'functions.ipynb',
#  'ifelsecondt.ipynb',
#  'listcomphr.ipynb',
#  'Lists.ipynb',
#  'methods.ipynb',
#  'oops.ipynb',
#  'open&readingfiles.ipynb',
#  'sets&boolean.ipynb',
#  'stringIndexing-slicing.ipynb',
#  'Tuple.ipynb',
#  'Untitled.ipynb',
#  'Untitled1.ipynb',
#  'Untitled2.ipynb',
#  'Untitled3.ipynb',
#  'usefulOperators.ipynb',
#  'whileloop.ipynb']

# %%
import send2trash

# %% [markdown]
# time an date module

# %%
import datetime

# %%
mytime = datetime.time(2)

# %%
mytime.hour
# Out:
# 2

# %%
print(mytime)
# Out:
# 02:00:00
