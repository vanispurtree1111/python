# %%
# extract the title

# %%
import requests

# %%
import bs4

# %%
result = requests.get("https://en.wikipedia.org/wiki/Charles_Babbage")

# %%
type(result)
# Out:
# requests.models.Response

# %%
result.text
# Out:
# '<!DOCTYPE html>\n<html class="client-nojs vector-feature-language-in-header-enabled vector-feature-language-in-main-page-header-disabled vector-feature-page-tools-pinned-disabled vector-feature-toc-pinned-clientpref-1 vector-feature-main-menu-pinned-disabled vector-feature-limited-width-clientpref-1 vector-feature-limited-width-content-enabled vector-feature-custom-font-size-clientpref-1 vector-feature-appearance-pinned-clientpref-1 vector-feature-night-mode-enabled skin-theme-clientpref-day vector-sticky-header-enabled vector-toc-available" lang="en" dir="ltr">\n<head>\n<meta charset="UTF-8">\n<title>Charles Babbage - Wikipedia</title>\n<script>(function(){var className="client-js vector-feature-language-in-header-enabled vector-feature-language-in-main-page-header-disabled vector-feature-page-tools-pinned-disabled vector-feature-toc-pinned-clientpref-1 vector-feature-main-menu-pinned-disabled vector-feature-limited-width-clientpref-1 vector-feature-limited-width-content-enabled ve
# ...

# %%
import bs4

# %%
soup = bs4.BeautifulSoup(result.text,"lxml")

# %%
soup
# Out:
# <!DOCTYPE html>
# <html class="client-nojs vector-feature-language-in-header-enabled vector-feature-language-in-main-page-header-disabled vector-feature-page-tools-pinned-disabled vector-feature-toc-pinned-clientpref-1 vector-feature-main-menu-pinned-disabled vector-feature-limited-width-clientpref-1 vector-feature-limited-width-content-enabled vector-feature-custom-font-size-clientpref-1 vector-feature-appearance-pinned-clientpref-1 vector-feature-night-mode-enabled skin-theme-clientpref-day vector-sticky-header-enabled vector-toc-available" dir="ltr" lang="en">
# <head>
# <meta charset="utf-8"/>
# <title>Charles Babbage - Wikipedia</title>
# ...

# %%
soup.select('title')
# Out:
# [<title>Charles Babbage - Wikipedia</title>]

# %%
soup.select('title')[0].getText()
# Out:
# 'Charles Babbage - Wikipedia'

# %%
siteparagraphs =soup.select("p")

# %%
siteparagraphs[0]
# Out:
# <p class="cdx-dialog__header__subtitle">This is an accepted version of this page</p>

# %%
siteparagraphs[0].getText()
# Out:
# 'This is an accepted version of this page'

# %% [markdown]
# Grabbing a class

# %%
soup.select('infobox-label')
# Out:
# []

# %%
result = requests.get("https://en.wikipedia.org/wiki/Charles_Babbage")

# %%
result.text
# Out:
# '<!DOCTYPE html>\n<html class="client-nojs vector-feature-language-in-header-enabled vector-feature-language-in-main-page-header-disabled vector-feature-page-tools-pinned-disabled vector-feature-toc-pinned-clientpref-1 vector-feature-main-menu-pinned-disabled vector-feature-limited-width-clientpref-1 vector-feature-limited-width-content-enabled vector-feature-custom-font-size-clientpref-1 vector-feature-appearance-pinned-clientpref-1 vector-feature-night-mode-enabled skin-theme-clientpref-day vector-sticky-header-enabled vector-toc-available" lang="en" dir="ltr">\n<head>\n<meta charset="UTF-8">\n<title>Charles Babbage - Wikipedia</title>\n<script>(function(){var className="client-js vector-feature-language-in-header-enabled vector-feature-language-in-main-page-header-disabled vector-feature-page-tools-pinned-disabled vector-feature-toc-pinned-clientpref-1 vector-feature-main-menu-pinned-disabled vector-feature-limited-width-clientpref-1 vector-feature-limited-width-content-enabled ve
# ...

# %%
soup = bs4.BeautifulSoup(result.text,"lxml")

# %%
soup.select('.infobox-label')
# Out:
# [<th class="infobox-label" scope="row">Born</th>,
#  <th class="infobox-label" scope="row">Died</th>,
#  <th class="infobox-label" scope="row">Alma mater</th>,
#  <th class="infobox-label" scope="row">Known for</th>,
#  <th class="infobox-label" scope="row">Spouse</th>,
#  <th class="infobox-label" scope="row">Children</th>,
#  <th class="infobox-label" scope="row">Relatives</th>,
#  <th class="infobox-label" scope="row">Awards</th>,
#  <th class="infobox-label" scope="row">Fields</th>,
#  <th class="infobox-label" scope="row">Institutions</th>]

# %%
for item in soup.select('.infobox-label'):
    print(item.text)
# Out:
# Born
# Died
# Alma mater
# Known for
# Spouse
# Children
# Relatives
# Awards
# Fields
# Institutions

# %% [markdown]
# grabbing an image

# %%
res = requests.get("https://en.wikipedia.org/wiki/Nature")

# %%
type(res)
# Out:
# requests.models.Response

# %%
soup = bs4.BeautifulSoup(res.text,"lxml")

# %%
soup
# Out:
# <!DOCTYPE html>
# <html class="client-nojs vector-feature-language-in-header-enabled vector-feature-language-in-main-page-header-disabled vector-feature-page-tools-pinned-disabled vector-feature-toc-pinned-clientpref-1 vector-feature-main-menu-pinned-disabled vector-feature-limited-width-clientpref-1 vector-feature-limited-width-content-enabled vector-feature-custom-font-size-clientpref-1 vector-feature-appearance-pinned-clientpref-1 vector-feature-night-mode-enabled skin-theme-clientpref-day vector-sticky-header-enabled vector-toc-available" dir="ltr" lang="en">
# <head>
# <meta charset="utf-8"/>
# <title>Nature - Wikipedia</title>
# ...

# %%
soup.select('img')
# Out:
# [<img alt="" aria-hidden="true" class="mw-logo-icon" height="50" src="/static/images/icons/wikipedia.png" width="50"/>,
#  <img alt="Wikipedia" class="mw-logo-wordmark" src="/static/images/mobile/copyright/wikipedia-wordmark-en.svg" style="width: 7.5em; height: 1.125em;"/>,
#  <img alt="The Free Encyclopedia" class="mw-logo-tagline" height="13" src="/static/images/mobile/copyright/wikipedia-tagline-en.svg" style="width: 7.3125em; height: 0.8125em;" width="117"/>,
#  <img alt="Page semi-protected" class="mw-file-element" data-file-height="512" data-file-width="512" decoding="async" height="20" src="//upload.wikimedia.org/wikipedia/en/thumb/1/1b/Semi-protection-shackle.svg/20px-Semi-protection-shackle.svg.png" srcset="//upload.wikimedia.org/wikipedia/en/thumb/1/1b/Semi-protection-shackle.svg/30px-Semi-protection-shackle.svg.png 1.5x, //upload.wikimedia.org/wikipedia/en/thumb/1/1b/Semi-protection-shackle.svg/40px-Semi-protection-shackle.svg.png 2x" width="20"/>,
# ...

# %%
soup.select('.mw-file-element')
# Out:
# [<img alt="Page semi-protected" class="mw-file-element" data-file-height="512" data-file-width="512" decoding="async" height="20" src="//upload.wikimedia.org/wikipedia/en/thumb/1/1b/Semi-protection-shackle.svg/20px-Semi-protection-shackle.svg.png" srcset="//upload.wikimedia.org/wikipedia/en/thumb/1/1b/Semi-protection-shackle.svg/30px-Semi-protection-shackle.svg.png 1.5x, //upload.wikimedia.org/wikipedia/en/thumb/1/1b/Semi-protection-shackle.svg/40px-Semi-protection-shackle.svg.png 2x" width="20"/>,
# ...

# %%
computer = soup.select('.mw-file-element')[1]

# %%
computer
# Out:
# <img class="mw-file-element" data-file-height="4244" data-file-width="5179" decoding="async" height="238" src="//upload.wikimedia.org/wikipedia/commons/thumb/0/06/Startrails_above_Gunung_Bromo_-_Indonesia.jpg/290px-Startrails_above_Gunung_Bromo_-_Indonesia.jpg" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/0/06/Startrails_above_Gunung_Bromo_-_Indonesia.jpg/435px-Startrails_above_Gunung_Bromo_-_Indonesia.jpg 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/0/06/Startrails_above_Gunung_Bromo_-_Indonesia.jpg/580px-Startrails_above_Gunung_Bromo_-_Indonesia.jpg 2x" width="290"/>

# %%
computer['src']
# Out:
# '//upload.wikimedia.org/wikipedia/commons/thumb/0/06/Startrails_above_Gunung_Bromo_-_Indonesia.jpg/290px-Startrails_above_Gunung_Bromo_-_Indonesia.jpg'

# %% [markdown]
# <img src="//upload.wikimedia.org/wikipedia/commons/thumb/0/06/Startrails_above_Gunung_Bromo_-_Indonesia.jpg/290px-Startrails_above_Gunung_Bromo_-_Indonesia.jpg">
# >

# %%
image_link = requests.get('https://upload.wikimedia.org/wikipedia/commons/thumb/0/06/Startrails_above_Gunung_Bromo_-_Indonesia.jpg/290px-Startrails_above_Gunung_Bromo_-_Indonesia.jpg')

# %%
# image_link.content

# %%
f = open('my_computer_image.jpg','wb')

# %%
f.write(image_link.content)
# Out:
# 17324

# %%
f.close()

# %% [markdown]
# webscrapping with multiple items

# %%
import requests
import bs4

# %%
https://books.toscrape.com/catalogue/page-2.html

# %%
https://books.toscrape.com/catalogue/page-3.html

# %%
base_url = 'https://books.toscrape.com/catalogue/page-{}.html'

# %%
page_num = 12
base_url.format('20')
# Out:
# 'https://books.toscrape.com/catalogue/page-20.html'

# %%
res = requests.get(base_url.format(1))

# %%
soup = bs4.BeautifulSoup(res.text,'lxml')

# %%
soup.select(".product_pod")
# Out:
# [<article class="product_pod">
#  <div class="image_container">
#  <a href="a-light-in-the-attic_1000/index.html"><img alt="A Light in the Attic" class="thumbnail" src="../media/cache/2c/da/2cdad67c44b002e7ead0cc35693c0e8b.jpg"/></a>
#  </div>
#  <p class="star-rating Three">
#  <i class="icon-star"></i>
#  <i class="icon-star"></i>
#  <i class="icon-star"></i>
#  <i class="icon-star"></i>
#  <i class="icon-star"></i>
#  </p>
#  <h3><a href="a-light-in-the-attic_1000/index.html" title="A Light in the Attic">A Light in the ...</a></h3>
#  <div class="product_price">
#  <p class="price_color">Â£51.77</p>
#  <p class="instock availability">
#  <i class="icon-ok"></i>
#
#          In stock
#
#  </p>
#  <form>
#  <button class="btn btn-primary btn-block" data-loading-text="Adding..." type="submit">Add to basket</button>
#  </form>
#  </div>
#  </article>,
#  <article class="product_pod">
#  <div class="image_container">
# ...
