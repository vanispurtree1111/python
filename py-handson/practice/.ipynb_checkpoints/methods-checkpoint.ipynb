# %%
mylist = [1,2,3]

# %%
mylist.append(4)
mylist
# Out:
# [1, 2, 3, 4]

# %% [markdown]
# if we give the method itself without adding the data it will give the syntax or documentation

# %%
mylist.insert
# Out:
# <function list.insert(index, object, /)>

# %%
help(mylist.insert)
# Out:
# Help on built-in function insert:
#
# insert(index, object, /) method of builtins.list instance
#     Insert object before index.
