# %%
myString = "pythonprogram"

# %%
myString[1:]
# to print the string leaving 1st index
# Out:
# 'ythonprogram'

# %%
myString[::-1]   
# to reverse the string
# Out:
# 'margorpnohtyp'

# %%
myString[-2:]
# Out:
# 'am'

# %%
text="hereisthestring"
# text[2:]  to print from start leaving first two index  #output : 'reisthestring'
# text[:3]  to print from end  #output : 'her'

# %%
text[:3]
# Out:
# 'her'

# %%
# format in string
print('this is format {}'.format('string'))
# Out:
# this is format string

# %%
result = 'this is how we can add more items in sentence {} {} {}'.format('apple','mango','blueberry')
print(result)
# Out:
# this is how we can add more items in sentence apple mango blueberry

# %%
res= 'this is to add by the help of index {0} {0} {0}'.format('apple','mango','blueberry')
print(res)
# Out:
# this is to add by the help of index apple apple apple

# %%
resu='this is to add by there assigned variables {a} {b} {c}'.format(a='apple',b='banana',c='carrot')
print(resu)
# Out:
# this is to add by there assigned variables apple banana carrot

# %%
# float formatting 
result = 0.123874394
# syntax = "{value:width:precision f}"
print("the result was {r:1.5f}".format(r=result))
# Out:
# the result was 0.12387

# %%
# fromatted string literal (basically replacing the .formate(name) with f string)
name = "jose"
# print('hello, his name is {}'.format(name))   we are replacing this sentence with the f to accesss the variable int he sentence
print(f'hello,his name is {name}')
# Out:
# hello,his name is jose

# %%
name = "vani" 
age = 25
place = "tumkur"
print(f'my name is {name} and iam {age} old , iam from {place}')
# Out:
# my name is vani and iam 25 old , iam from tumkur
