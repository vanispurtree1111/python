# %% [markdown]
# Advanced numbers

# %%
hex(14)
# Out:
# '0xe'

# %%
bin(1234)
# binary reprsentation of numbers
# Out:
# '0b10011010010'

# %%
2**4
# Out:
# 16

# %%
pow(2,4)
# Out:
# 16

# %%
abs(-3)
# Out:
# 3

# %%
round(2.458)
# Out:
# 2

# %%
# string 
s = 'hello world'

# %%
s.capitalize()
# Out:
# 'Hello world'

# %%
s.center(20,'z')
# Out:
# 'zzzzhello worldzzzzz'

# %%
s = 'helo'

# %%
s.isalnum()
# Out:
# True

# %%
s.isalpha()
# Out:
# True
