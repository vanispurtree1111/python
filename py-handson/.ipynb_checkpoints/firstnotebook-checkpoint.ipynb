# %%
a = 10

# %%
a= a+a

# %%
a
# Out:
# 40

# %%
a= a+ a

# %%
a
# Out:
# 80

# %%
type(a)
# Out:
# int

# %%
b = [10, "vani", 8.9]
type(b)
# Out:
# list

# %%
c = (4,3,5)
type(c)
# Out:
# tuple

# %%
d = { "name": "vani","age": "25"}
type(d)
# Out:
# dict

# %%
e = range(5)
e
# Out:
# range(0, 5)

# %%
type(e)
# Out:
# range
