# %% [markdown]
# Datatypes with its examples

# %% [markdown]
# 1.Int

# %%
a = 10 
print(a)
type(a)
# Out:
# 10
# int

# %% [markdown]
# 2. string

# %%
b ="vani"
print(b)
type(b)
# Out:
# vani
# str

# %% [markdown]
# 3. list

# %%
c= [ 10, "vani", 5.5 ]
print(c)
type(c)
# Out:
# [10, 'vani', 5.5]
# list

# %% [markdown]
# 4. tuple (immutable - once assigned the value , cnt change its value)

# %%
d = ( "vani", 10, 9.7)
print(d)
type(d)
# Out:
# ('vani', 10, 9.7)
# tuple

# %% [markdown]
# 5. range

# %%
e = range (5)
print(e)
type(e)
# Out:
# range(0, 5)
# range

# %% [markdown]
# 6. Set

# %%
f = { "paper","pen","bag"}
print(f)
type(f)
# Out:
# {'bag', 'paper', 'pen'}
# set
