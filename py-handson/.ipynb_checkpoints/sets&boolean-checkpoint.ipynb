# %%
myset = set()
# to add the unique value paied and represent we use set

# %%
myset.add(6)

# %%
myset
# Out:
# {6}

# %%
myset.add(2)

# %%
myset
# Out:
# {2, 6}

# %% [markdown]
# BOOLEAN
# it should de denoted with the capital letter True or False

# %%
True
# Out:
# True

# %%
1>10
# Out:
# False

# %%
10<100
# Out:
# True

# %%
1 == 1
# Out:
# True
