# %%
basic_lists = ['one','two','three']
# here is the example says how to define the lists and it allows indexing and slicing too. 
print(basic_lists)
# Out:
# ['one', 'two', 'three']

# %%
basic_lists[1] 
# here indexing function with the index values
# Out:
# 'two'

# %%
basic_lists[1:]
# Out:
# ['two', 'three']

# %%
basic_lists[::-1]
# Out:
# ['three', 'two', 'one']

# %%
list_step= ['1','2','3','4','5']

# %%
list_step[1:2] 
# step thing (doubt)
# Out:
# ['2']

# %%
list_step
# Out:
# ['1', '2', '3', '4', '5']

# %%
list_step.append('6')
# append only takes one argument to pass in the list . basically append is to add the item in the list

# %%
list_step.pop()
# pop is used to delete the last item in the list
# Out:
# '6'

# %%
list_step
# Out:
# ['1', '2', '3', '4', '5']

# %%
# we can remove the element of specific index by passing the index in the pop function 
list_step.pop(1)
# Out:
# '2'

# %%
list_step
# Out:
# ['1', '3', '4', '5']

# %% [markdown]
# SORT in python
# <!-- sort cant be assign to a variable directly . but after operation the sorted value can be assign it to the variable  -->

# %%
num_lists = [1,6,9,3,0,5]

# %%
num_lists.sort()
# here we got the sorted order of num_lists

# %%
num_lists
# Out:
# [0, 1, 3, 5, 6, 9]

# %% [markdown]
# REVERSE IN PYTHON
# syntax -
# .revrese()
# there is another way to do the reverse by using slicing
# ex: a = [1,2,3,4]
# a[::-1]
# it will reverse the list .

# %%
item =[1,2,3,4,5]

# %%
item.reverse()

# %%
item
# Out:
# [5, 4, 3, 2, 1]
