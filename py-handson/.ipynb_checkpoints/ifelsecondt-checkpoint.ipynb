# %%
if 2<3:
    print("ITS true")
# Out:
# ITS true

# %%
hungry = False

if hungry:
    print("feed me!!")
else:
    print("not hungry")
# Out:
# not hungry

# %%
loc = 'cafe'

if loc == 'Auto shop':
    print("cars are cool")
elif loc == 'Bank':
    print("money money money")
elif loc == 'cafe':
    print("have some icecream")
else:
    print("i dont know much")
# Out:
# have some icecream

# %%
name = ''
if name == 'frankie':
    print("hello frankie")
elif name == 'sammy':
    print("hello sammy")
else:
    print("what is your name")
# Out:
# what is your name
