# %%
from PIL import Image
# we installed pillow , but we import it as PIL

# %%
mac = Image.open('example.jpg')

# %%
mac
# in other environment we need to give mac.show() but in jypter we can give the above command to view
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1993x1257>

# %%
mac.size
# Out:
# (1993, 1257)

# %% [markdown]
# cropping images

# %%
mac.crop((0,0,100,100))
# Out:
# <PIL.Image.Image image mode=RGB size=100x100>

# %%
pencils = Image.open('pencils.jpg')

# %%
pencils
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1950x1300>

# %%
pencils.size
# Out:
# (1950, 1300)

# %%
# from top- crop
# # x= 0 
# # y=0
# # w= 1950/3
# # h = 1300/10

# to crop from bottom 
x= 0 
y=1100
w= 1950/3
h = 1300

# %%
pencils.crop((x,y,w,h))
# Out:
# <PIL.Image.Image image mode=RGB size=650x200>

# %%
mac
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1993x1257>

# %%
mac.size
# Out:
# (1993, 1257)

# %%
x =halfway-200
w = halfway +200
y = 800
h = 1257

# %%
mac.crop((x,y,w,h))
# Out:
# <PIL.Image.Image image mode=RGB size=400x457>

# %%
computer = mac.crop((x,y,w,h))

# %%
mac.paste(im=computer,box=(796,0))

# %%
mac
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1993x1257>

# %%
mac.size
# Out:
# (1993, 1257)

# %%
mac.resize((3000,500))
# Out:
# <PIL.Image.Image image mode=RGB size=3000x500>

# %%
# color Transparency
